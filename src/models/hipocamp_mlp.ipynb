# %% [markdown]
# # MLP com RFECV

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import os
import random
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# Tratamento da Random Seed

# %%
def set_seed(seed: int):
    random.seed(seed) # Python
    np.random.seed(seed)  # Numpy, é o gerador utilizado pelo sklearn
    os.environ["PYTHONHASHSEED"] = str(seed)  # sistema operativo

# Fixar a seed
set_seed(2023)

# %% [markdown]
# Load CSVs

# %%
df_train = pd.read_csv('../../datasets_manuseados/train_radiomics_hipocamp_treated.csv')
df_test = pd.read_csv('../../datasets_manuseados/test_radiomics_hipocamp_treated.csv')

# %% [markdown]
# Float64/Int64 to Float32/Int32

# %%
float_features = df_train.select_dtypes(include='float')
int_features = df_train.select_dtypes(include='int')
df_train[float_features.columns] = df_train[float_features.columns].astype(np.float32)
df_train[int_features.columns] = df_train[int_features.columns].astype(np.int32)
df_train.info()
print("--------------------")
float_features = df_test.select_dtypes(include='float')
int_features = df_test.select_dtypes(include='int')
df_test[float_features.columns] = df_test[float_features.columns].astype(np.float32)
df_test[int_features.columns] = df_test[int_features.columns].astype(np.int32)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 1902 entries, diagnostics_Image-original_Mean to Transition
# dtypes: float32(1901), object(1)
# memory usage: 2.2+ MB
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 1901 entries, diagnostics_Image-original_Mean to Age
# dtypes: float32(1901)
# memory usage: 742.7 KB

# %% [markdown]
# Train Test Split

# %%
X = df_train.drop(columns=['Transition'])
y = df_train['Transition']

X_test = df_test

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=2023, stratify = y)

# %% [markdown]
# ### Feature Selection using RFECV and PCA

# %%
model = RandomForestClassifier(random_state=2023)

### 1. RFECV - Recursive Feature Elimination with Cross-Validation
rfecv = RFECV(estimator=model, step=1, cv=StratifiedKFold(3), scoring='f1_macro', n_jobs=-1, verbose=2)
rfecv.fit(X, y)

rfecv_features = X.columns[rfecv.support_]
print(f"Number of selected features by RFECV: {len(rfecv_features)}")
print(f"Eliminated features by RFECV: {len(X.columns) - len(rfecv_features)}")

plt.figure()
plt.xlabel("Number of selected features")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.title("RFECV - Score vs. Number of Features")
plt.plot(range(1, len(rfecv.cv_results_['mean_test_score']) + 1), rfecv.cv_results_['mean_test_score'])
plt.show()

X_rfecv = X[rfecv_features]
X_test_rfecv = X_test[rfecv_features]
X_train_rfecv = X_train[rfecv_features]
X_val_rfecv = X_val[rfecv_features]

### 2. PCA - Principal Component Analysis
pca = PCA(n_components=0.95)
X_final = pca.fit_transform(X_rfecv)
X_test_final = pca.transform(X_test_rfecv)
X_train_final = pca.transform(X_train_rfecv)
X_val_final = pca.transform(X_val_rfecv)
print(f"Original number of features (after RFECV): {X_rfecv.shape[1]}")
print(f"Number of components selected by PCA: {pca.n_components_}")

plt.figure()
plt.bar(range(1, pca.n_components_ + 1), pca.explained_variance_ratio_, color='blue', alpha=0.7)
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("PCA - Principal Components Explained Variance Ratio")
plt.show()

# Final datasets for training and testing
print(f"Final shape of the train dataset: {X_final.shape}")
print(f"Final shape of the test dataset: {X_test_final.shape}")
print(f"Final shape of the training part of the train dataset: {X_train_final.shape}")
print(f"Final shape of the testing part of the train dataset: {X_val_final.shape}")
# Out:
# Fitting estimator with 1901 features.
# Fitting estimator with 1901 features.
# Fitting estimator with 1901 features.
# Fitting estimator with 1900 features.
# Fitting estimator with 1900 features.
# Fitting estimator with 1900 features.
# Fitting estimator with 1899 features.
# Fitting estimator with 1899 features.
# Fitting estimator with 1899 features.
# Fitting estimator with 1898 features.
# Fitting estimator with 1898 features.
# Fitting estimator with 1898 features.
# Fitting estimator with 1897 features.
# Fitting estimator with 1897 features.
# Fitting estimator with 1897 features.
# Fitting estimator with 1896 features.
# Fitting estimator with 1896 features.
# Fitting estimator with 1896 features.
# Fitting estimator with 1895 features.
# Fitting estimator with 1895 features.
# Fitting estimator with 1895 features.
# Fitting estimator with 1894 features.
# Fitting estimator with 1894 features.
# Fitting estimator with 1894 features.
# Fitting estimator with 1893 features.
# Fitting estimator with 1893 features.
# Fitting estimator with 1893 features.
# Fitting estimator with 1892 features.
# Fitting estimator with 1892 features.
# Fitting estimator with 1892 features.
# Fitting estimator with 1891 features.
# Fitting estimator with 1891 features.
# Fitting estimator with 1891 features.
# Fitting estimator with 1890 features.
# Fitting estimator with 1890 features.
# Fitting estimator with 1890 features.
# Fitting estimator with 1889 features.
# Fitting estimator with 1889 features.
# Fitting estimator with 1889 features.
# Fitting estimator with 1888 features.
# Fitting estimator with 1888 features.
# Fitting estimator with 1888 features.
# Fitting estimator with 1887 features.
# Fitting estimator with 1887 features.
# Fitting estimator with 1887 features.
# Fitting estimator with 1886 features.
# Fitting estimator with 1886 features.
# Fitting estimator with 1886 features.
# Fitting estimator with 1885 features.
# Fitting estimator with 1885 features.
# Fitting estimator with 1885 features.
# Fitting estimator with 1884 features.
# Fitting estimator with 1884 features.
# Fitting estimator with 1884 features.
# Fitting estimator with 1883 features.
# Fitting estimator with 1883 features.
# Fitting estimator with 1883 features.
# Fitting estimator with 1882 features.
# Fitting estimator with 1882 features.
# Fitting estimator with 1882 features.
# Fitting estimator with 1881 features.
# Fitting estimator with 1881 features.
# Fitting estimator with 1881 features.
# Fitting estimator with 1880 features.
# Fitting estimator with 1880 features.
# Fitting estimator with 1880 features.
# Fitting estimator with 1879 features.
# Fitting estimator with 1879 features.
# Fitting estimator with 1879 features.
# Fitting estimator with 1878 features.
# Fitting estimator with 1878 features.
# Fitting estimator with 1878 features.
# Fitting estimator with 1877 features.
# Fitting estimator with 1877 features.
# Fitting estimator with 1877 features.
# Fitting estimator with 1876 features.
# Fitting estimator with 1876 features.
# Fitting estimator with 1876 features.
# Fitting estimator with 1875 features.
# Fitting estimator with 1875 features.
# Fitting estimator with 1875 features.
# Fitting estimator with 1874 features.
# Fitting estimator with 1874 features.
# Fitting estimator with 1874 features.
# Fitting estimator with 1873 features.
# Fitting estimator with 1873 features.
# Fitting estimator with 1873 features.
# Fitting estimator with 1872 features.
# Fitting estimator with 1872 features.
# Fitting estimator with 1872 features.
# Fitting estimator with 1871 features.
# Fitting estimator with 1871 features.
# Fitting estimator with 1871 features.
# Fitting estimator with 1870 features.
# Fitting estimator with 1870 features.
# Fitting estimator with 1870 features.
# Fitting estimator with 1869 features.
# Fitting estimator with 1869 features.
# Fitting estimator with 1869 features.
# Fitting estimator with 1868 features.
# Fitting estimator with 1868 features.
# Fitting estimator with 1868 features.
# Fitting estimator with 1867 features.
# Fitting estimator with 1867 features.
# Fitting estimator with 1867 features.
# Fitting estimator with 1866 features.
# Fitting estimator with 1866 features.
# Fitting estimator with 1866 features.
# Fitting estimator with 1865 features.
# Fitting estimator with 1865 features.
# Fitting estimator with 1865 features.
# Fitting estimator with 1864 features.
# Fitting estimator with 1864 features.
# Fitting estimator with 1864 features.
# Fitting estimator with 1863 features.
# Fitting estimator with 1863 features.
# Fitting estimator with 1863 features.
# Fitting estimator with 1862 features.
# Fitting estimator with 1862 features.
# Fitting estimator with 1862 features.
# Fitting estimator with 1861 features.
# Fitting estimator with 1861 features.
# Fitting estimator with 1861 features.
# Fitting estimator with 1860 features.
# Fitting estimator with 1860 features.
# Fitting estimator with 1860 features.
# Fitting estimator with 1859 features.
# Fitting estimator with 1859 features.
# Fitting estimator with 1859 features.
# Fitting estimator with 1858 features.
# Fitting estimator with 1858 features.
# Fitting estimator with 1858 features.
# Fitting estimator with 1857 features.
# Fitting estimator with 1857 features.
# Fitting estimator with 1856 features.
# Fitting estimator with 1857 features.
# Fitting estimator with 1856 features.
# Fitting estimator with 1855 features.
# Fitting estimator with 1856 features.
# Fitting estimator with 1855 features.
# Fitting estimator with 1854 features.
# Fitting estimator with 1855 features.
# Fitting estimator with 1854 features.
# Fitting estimator with 1853 features.
# Fitting estimator with 1854 features.
# Fitting estimator with 1853 features.
# Fitting estimator with 1852 features.
# Fitting estimator with 1853 features.
# Fitting estimator with 1852 features.
# Fitting estimator with 1851 features.
# Fitting estimator with 1852 features.
# Fitting estimator with 1851 features.
# Fitting estimator with 1850 features.
# Fitting estimator with 1851 features.
# Fitting estimator with 1850 features.
# Fitting estimator with 1849 features.
# Fitting estimator with 1850 features.
# Fitting estimator with 1849 features.
# Fitting estimator with 1848 features.
# Fitting estimator with 1849 features.
# Fitting estimator with 1848 features.
# Fitting estimator with 1847 features.
# Fitting estimator with 1848 features.
# Fitting estimator with 1847 features.
# Fitting estimator with 1846 features.
# Fitting estimator with 1846 features.
# Fitting estimator with 1847 features.
# Fitting estimator with 1845 features.
# Fitting estimator with 1845 features.
# Fitting estimator with 1846 features.
# Fitting estimator with 1844 features.
# Fitting estimator with 1844 features.
# Fitting estimator with 1845 features.
# Fitting estimator with 1843 features.
# Fitting estimator with 1843 features.
# Fitting estimator with 1844 features.
# Fitting estimator with 1842 features.
# Fitting estimator with 1842 features.
# Fitting estimator with 1843 features.
# Fitting estimator with 1841 features.
# Fitting estimator with 1841 features.
# Fitting estimator with 1842 features.
# Fitting estimator with 1840 features.
# Fitting estimator with 1840 features.
# Fitting estimator with 1841 features.
# Fitting estimator with 1839 features.
# Fitting estimator with 1839 features.
# Fitting estimator with 1840 features.
# Fitting estimator with 1838 features.
# Fitting estimator with 1838 features.
# Fitting estimator with 1839 features.
# Fitting estimator with 1837 features.
# Fitting estimator with 1837 features.
# Fitting estimator with 1838 features.
# Fitting estimator with 1836 features.
# Fitting estimator with 1836 features.
# Fitting estimator with 1837 features.
# Fitting estimator with 1835 features.
# Fitting estimator with 1835 features.
# Fitting estimator with 1836 features.
# Fitting estimator with 1834 features.
# Fitting estimator with 1834 features.
# Fitting estimator with 1835 features.
# Fitting estimator with 1833 features.
# Fitting estimator with 1833 features.
# Fitting estimator with 1834 features.
# Fitting estimator with 1832 features.
# Fitting estimator with 1832 features.
# Fitting estimator with 1833 features.
# Fitting estimator with 1831 features.
# Fitting estimator with 1831 features.
# Fitting estimator with 1832 features.
# Fitting estimator with 1830 features.
# Fitting estimator with 1830 features.
# Fitting estimator with 1831 features.
# Fitting estimator with 1829 features.
# Fitting estimator with 1829 features.
# Fitting estimator with 1830 features.
# Fitting estimator with 1828 features.
# Fitting estimator with 1828 features.
# Fitting estimator with 1829 features.
# Fitting estimator with 1827 features.
# Fitting estimator with 1827 features.
# Fitting estimator with 1828 features.
# Fitting estimator with 1826 features.
# Fitting estimator with 1826 features.
# Fitting estimator with 1827 features.
# Fitting estimator with 1825 features.
# Fitting estimator with 1825 features.
# Fitting estimator with 1826 features.
# Fitting estimator with 1824 features.
# Fitting estimator with 1824 features.
# Fitting estimator with 1825 features.
# Fitting estimator with 1823 features.
# Fitting estimator with 1823 features.
# Fitting estimator with 1824 features.
# Fitting estimator with 1822 features.
# Fitting estimator with 1822 features.
# Fitting estimator with 1823 features.
# Fitting estimator with 1821 features.
# Fitting estimator with 1821 features.
# Fitting estimator with 1822 features.
# Fitting estimator with 1820 features.
# Fitting estimator with 1820 features.
# Fitting estimator with 1821 features.
# Fitting estimator with 1819 features.
# Fitting estimator with 1819 features.
# Fitting estimator with 1820 features.
# Fitting estimator with 1818 features.
# Fitting estimator with 1818 features.
# Fitting estimator with 1819 features.
# Fitting estimator with 1817 features.
# Fitting estimator with 1817 features.
# Fitting estimator with 1818 features.
# Fitting estimator with 1816 features.
# Fitting estimator with 1816 features.
# Fitting estimator with 1817 features.
# Fitting estimator with 1815 features.
# Fitting estimator with 1815 features.
# Fitting estimator with 1816 features.
# Fitting estimator with 1814 features.
# Fitting estimator with 1814 features.
# Fitting estimator with 1815 features.
# Fitting estimator with 1813 features.
# Fitting estimator with 1813 features.
# Fitting estimator with 1814 features.
# Fitting estimator with 1812 features.
# Fitting estimator with 1812 features.
# Fitting estimator with 1811 features.
# Fitting estimator with 1813 features.
# Fitting estimator with 1811 features.
# Fitting estimator with 1810 features.
# Fitting estimator with 1812 features.
# Fitting estimator with 1810 features.
# Fitting estimator with 1809 features.
# Fitting estimator with 1811 features.
# Fitting estimator with 1809 features.
# Fitting estimator with 1808 features.
# Fitting estimator with 1810 features.
# Fitting estimator with 1808 features.
# Fitting estimator with 1807 features.
# Fitting estimator with 1809 features.
# Fitting estimator with 1807 features.
# Fitting estimator with 1806 features.
# Fitting estimator with 1808 features.
# Fitting estimator with 1806 features.
# Fitting estimator with 1805 features.
# Fitting estimator with 1807 features.
# Fitting estimator with 1805 features.
# Fitting estimator with 1804 features.
# Fitting estimator with 1806 features.
# Fitting estimator with 1804 features.
# Fitting estimator with 1803 features.
# Fitting estimator with 1805 features.
# Fitting estimator with 1803 features.
# Fitting estimator with 1802 features.
# Fitting estimator with 1804 features.
# Fitting estimator with 1802 features.
# Fitting estimator with 1801 features.
# Fitting estimator with 1801 features.
# Fitting estimator with 1803 features.
# Fitting estimator with 1800 features.
# Fitting estimator with 1800 features.
# Fitting estimator with 1802 features.
# Fitting estimator with 1799 features.
# Fitting estimator with 1799 features.
# Fitting estimator with 1801 features.
# Fitting estimator with 1798 features.
# Fitting estimator with 1798 features.
# Fitting estimator with 1800 features.
# Fitting estimator with 1797 features.
# Fitting estimator with 1797 features.
# Fitting estimator with 1799 features.
# Fitting estimator with 1796 features.
# Fitting estimator with 1796 features.
# Fitting estimator with 1798 features.
# Fitting estimator with 1795 features.
# Fitting estimator with 1795 features.
# Fitting estimator with 1797 features.
# Fitting estimator with 1794 features.
# Fitting estimator with 1794 features.
# Fitting estimator with 1796 features.
# Fitting estimator with 1793 features.
# Fitting estimator with 1793 features.
# Fitting estimator with 1795 features.
# Fitting estimator with 1792 features.
# Fitting estimator with 1792 features.
# Fitting estimator with 1794 features.
# Fitting estimator with 1791 features.
# Fitting estimator with 1791 features.
# Fitting estimator with 1790 features.
# Fitting estimator with 1793 features.
# Fitting estimator with 1790 features.
# Fitting estimator with 1789 features.
# Fitting estimator with 1792 features.
# Fitting estimator with 1789 features.
# Fitting estimator with 1788 features.
# Fitting estimator with 1791 features.
# Fitting estimator with 1788 features.
# Fitting estimator with 1787 features.
# Fitting estimator with 1790 features.
# Fitting estimator with 1787 features.
# Fitting estimator with 1786 features.
# Fitting estimator with 1789 features.
# Fitting estimator with 1786 features.
# Fitting estimator with 1785 features.
# Fitting estimator with 1788 features.
# Fitting estimator with 1785 features.
# Fitting estimator with 1784 features.
# Fitting estimator with 1787 features.
# Fitting estimator with 1784 features.
# Fitting estimator with 1783 features.
# Fitting estimator with 1786 features.
# Fitting estimator with 1783 features.
# Fitting estimator with 1782 features.
# Fitting estimator with 1785 features.
# Fitting estimator with 1782 features.
# Fitting estimator with 1781 features.
# Fitting estimator with 1784 features.
# Fitting estimator with 1781 features.
# Fitting estimator with 1780 features.
# Fitting estimator with 1783 features.
# Fitting estimator with 1780 features.
# Fitting estimator with 1779 features.
# Fitting estimator with 1782 features.
# Fitting estimator with 1779 features.
# Fitting estimator with 1778 features.
# Fitting estimator with 1781 features.
# Fitting estimator with 1778 features.
# Fitting estimator with 1777 features.
# Fitting estimator with 1780 features.
# Fitting estimator with 1777 features.
# Fitting estimator with 1776 features.
# Fitting estimator with 1779 features.
# Fitting estimator with 1776 features.
# Fitting estimator with 1775 features.
# Fitting estimator with 1778 features.
# Fitting estimator with 1775 features.
# Fitting estimator with 1774 features.
# Fitting estimator with 1777 features.
# Fitting estimator with 1774 features.
# Fitting estimator with 1773 features.
# Fitting estimator with 1773 features.
# Fitting estimator with 1776 features.
# Fitting estimator with 1772 features.
# Fitting estimator with 1772 features.
# Fitting estimator with 1775 features.
# Fitting estimator with 1771 features.
# Fitting estimator with 1771 features.
# Fitting estimator with 1774 features.
# Fitting estimator with 1770 features.
# Fitting estimator with 1770 features.
# Fitting estimator with 1773 features.
# Fitting estimator with 1769 features.
# Fitting estimator with 1769 features.
# Fitting estimator with 1772 features.
# Fitting estimator with 1768 features.
# Fitting estimator with 1768 features.
# Fitting estimator with 1771 features.
# Fitting estimator with 1767 features.
# Fitting estimator with 1767 features.
# Fitting estimator with 1770 features.
# Fitting estimator with 1766 features.
# Fitting estimator with 1766 features.
# Fitting estimator with 1769 features.
# Fitting estimator with 1765 features.
# Fitting estimator with 1765 features.
# Fitting estimator with 1768 features.
# Fitting estimator with 1764 features.
# Fitting estimator with 1764 features.
# Fitting estimator with 1767 features.
# Fitting estimator with 1763 features.
# Fitting estimator with 1763 features.
# Fitting estimator with 1766 features.
# Fitting estimator with 1762 features.
# Fitting estimator with 1762 features.
# Fitting estimator with 1765 features.
# Fitting estimator with 1761 features.
# Fitting estimator with 1761 features.
# Fitting estimator with 1764 features.
# Fitting estimator with 1760 features.
# Fitting estimator with 1760 features.
# Fitting estimator with 1763 features.
# Fitting estimator with 1759 features.
# Fitting estimator with 1759 features.
# Fitting estimator with 1762 features.
# Fitting estimator with 1758 features.
# Fitting estimator with 1758 features.
# Fitting estimator with 1761 features.
# Fitting estimator with 1757 features.
# Fitting estimator with 1757 features.
# Fitting estimator with 1760 features.
# Fitting estimator with 1756 features.
# Fitting estimator with 1756 features.
# Fitting estimator with 1759 features.
# Fitting estimator with 1755 features.
# Fitting estimator with 1755 features.
# Fitting estimator with 1758 features.
# Fitting estimator with 1754 features.
# Fitting estimator with 1754 features.
# Fitting estimator with 1757 features.
# Fitting estimator with 1753 features.
# Fitting estimator with 1753 features.
# Fitting estimator with 1756 features.
# Fitting estimator with 1752 features.
# Fitting estimator with 1752 features.
# Fitting estimator with 1755 features.
# Fitting estimator with 1751 features.
# Fitting estimator with 1751 features.
# Fitting estimator with 1750 features.
# Fitting estimator with 1754 features.
# Fitting estimator with 1750 features.
# Fitting estimator with 1749 features.
# Fitting estimator with 1753 features.
# Fitting estimator with 1749 features.
# Fitting estimator with 1748 features.
# Fitting estimator with 1752 features.
# Fitting estimator with 1748 features.
# Fitting estimator with 1747 features.
# Fitting estimator with 1751 features.
# Fitting estimator with 1747 features.
# Fitting estimator with 1746 features.
# Fitting estimator with 1750 features.
# Fitting estimator with 1746 features.
# Fitting estimator with 1745 features.
# Fitting estimator with 1749 features.
# Fitting estimator with 1745 features.
# Fitting estimator with 1744 features.
# Fitting estimator with 1748 features.
# Fitting estimator with 1744 features.
# Fitting estimator with 1743 features.
# Fitting estimator with 1747 features.
# Fitting estimator with 1743 features.
# Fitting estimator with 1742 features.
# Fitting estimator with 1746 features.
# Fitting estimator with 1742 features.
# Fitting estimator with 1741 features.
# Fitting estimator with 1745 features.
# Fitting estimator with 1741 features.
# Fitting estimator with 1740 features.
# Fitting estimator with 1744 features.
# Fitting estimator with 1740 features.
# Fitting estimator with 1739 features.
# Fitting estimator with 1743 features.
# Fitting estimator with 1739 features.
# Fitting estimator with 1738 features.
# Fitting estimator with 1742 features.
# Fitting estimator with 1738 features.
# Fitting estimator with 1737 features.
# Fitting estimator with 1741 features.
# Fitting estimator with 1737 features.
# Fitting estimator with 1736 features.
# Fitting estimator with 1740 features.
# Fitting estimator with 1736 features.
# Fitting estimator with 1735 features.
# Fitting estimator with 1739 features.
# Fitting estimator with 1735 features.
# Fitting estimator with 1734 features.
# Fitting estimator with 1738 features.
# Fitting estimator with 1734 features.
# Fitting estimator with 1733 features.
# Fitting estimator with 1737 features.
# Fitting estimator with 1732 features.
# Fitting estimator with 1733 features.
# Fitting estimator with 1736 features.
# Fitting estimator with 1731 features.
# Fitting estimator with 1732 features.
# Fitting estimator with 1735 features.
# Fitting estimator with 1730 features.
# Fitting estimator with 1731 features.
# Fitting estimator with 1734 features.
# Fitting estimator with 1729 features.
# Fitting estimator with 1730 features.
# Fitting estimator with 1733 features.
# Fitting estimator with 1728 features.
# Fitting estimator with 1729 features.
# Fitting estimator with 1727 features.
# Fitting estimator with 1732 features.
# Fitting estimator with 1728 features.
# Fitting estimator with 1726 features.
# Fitting estimator with 1731 features.
# Fitting estimator with 1727 features.
# Fitting estimator with 1725 features.
# Fitting estimator with 1726 features.
# Fitting estimator with 1730 features.
# Fitting estimator with 1724 features.
# Fitting estimator with 1725 features.
# Fitting estimator with 1729 features.
# Fitting estimator with 1723 features.
# Fitting estimator with 1724 features.
# Fitting estimator with 1728 features.
# Fitting estimator with 1722 features.
# Fitting estimator with 1723 features.
# Fitting estimator with 1727 features.
# Fitting estimator with 1721 features.
# Fitting estimator with 1722 features.
# Fitting estimator with 1726 features.
# Fitting estimator with 1721 features.
# Fitting estimator with 1720 features.
# Fitting estimator with 1725 features.
# Fitting estimator with 1720 features.
# Fitting estimator with 1719 features.
# Fitting estimator with 1724 features.
# Fitting estimator with 1719 features.
# Fitting estimator with 1718 features.
# Fitting estimator with 1723 features.
# Fitting estimator with 1718 features.
# Fitting estimator with 1717 features.
# Fitting estimator with 1722 features.
# Fitting estimator with 1717 features.
# Fitting estimator with 1716 features.
# Fitting estimator with 1721 features.
# Fitting estimator with 1716 features.
# Fitting estimator with 1715 features.
# Fitting estimator with 1720 features.
# Fitting estimator with 1715 features.
# Fitting estimator with 1714 features.
# Fitting estimator with 1719 features.
# Fitting estimator with 1714 features.
# Fitting estimator with 1713 features.
# Fitting estimator with 1718 features.
# Fitting estimator with 1713 features.
# Fitting estimator with 1712 features.
# Fitting estimator with 1717 features.
# Fitting estimator with 1712 features.
# Fitting estimator with 1711 features.
# Fitting estimator with 1716 features.
# Fitting estimator with 1711 features.
# Fitting estimator with 1710 features.
# Fitting estimator with 1715 features.
# Fitting estimator with 1710 features.
# Fitting estimator with 1709 features.
# Fitting estimator with 1714 features.
# Fitting estimator with 1709 features.
# Fitting estimator with 1708 features.
# Fitting estimator with 1713 features.
# Fitting estimator with 1708 features.
# Fitting estimator with 1707 features.
# Fitting estimator with 1712 features.
# Fitting estimator with 1707 features.
# Fitting estimator with 1706 features.
# Fitting estimator with 1711 features.
# Fitting estimator with 1706 features.
# Fitting estimator with 1705 features.
# Fitting estimator with 1710 features.
# Fitting estimator with 1705 features.
# Fitting estimator with 1704 features.
# Fitting estimator with 1709 features.
# Fitting estimator with 1704 features.
# Fitting estimator with 1703 features.
# Fitting estimator with 1708 features.
# Fitting estimator with 1703 features.
# Fitting estimator with 1702 features.
# Fitting estimator with 1707 features.
# Fitting estimator with 1702 features.
# Fitting estimator with 1701 features.
# Fitting estimator with 1706 features.
# Fitting estimator with 1701 features.
# Fitting estimator with 1700 features.
# Fitting estimator with 1705 features.
# Fitting estimator with 1700 features.
# Fitting estimator with 1699 features.
# Fitting estimator with 1704 features.
# Fitting estimator with 1699 features.
# Fitting estimator with 1698 features.
# Fitting estimator with 1698 features.
# Fitting estimator with 1703 features.
# Fitting estimator with 1697 features.
# Fitting estimator with 1697 features.
# Fitting estimator with 1702 features.
# Fitting estimator with 1696 features.
# Fitting estimator with 1696 features.
# Fitting estimator with 1701 features.
# Fitting estimator with 1695 features.
# Fitting estimator with 1695 features.
# Fitting estimator with 1700 features.
# Fitting estimator with 1694 features.
# Fitting estimator with 1694 features.
# Fitting estimator with 1699 features.
# Fitting estimator with 1693 features.
# Fitting estimator with 1693 features.
# Fitting estimator with 1698 features.
# Fitting estimator with 1692 features.
# Fitting estimator with 1692 features.
# Fitting estimator with 1697 features.
# Fitting estimator with 1691 features.
# Fitting estimator with 1691 features.
# Fitting estimator with 1696 features.
# Fitting estimator with 1690 features.
# Fitting estimator with 1690 features.
# Fitting estimator with 1695 features.
# Fitting estimator with 1689 features.
# Fitting estimator with 1689 features.
# Fitting estimator with 1694 features.
# Fitting estimator with 1688 features.
# Fitting estimator with 1688 features.
# Fitting estimator with 1693 features.
# Fitting estimator with 1687 features.
# Fitting estimator with 1687 features.
# Fitting estimator with 1692 features.
# Fitting estimator with 1686 features.
# Fitting estimator with 1686 features.
# Fitting estimator with 1691 features.
# Fitting estimator with 1685 features.
# Fitting estimator with 1685 features.
# Fitting estimator with 1690 features.
# Fitting estimator with 1684 features.
# Fitting estimator with 1684 features.
# Fitting estimator with 1689 features.
# Fitting estimator with 1683 features.
# Fitting estimator with 1683 features.
# Fitting estimator with 1688 features.
# Fitting estimator with 1682 features.
# Fitting estimator with 1682 features.
# Fitting estimator with 1681 features.
# Fitting estimator with 1687 features.
# Fitting estimator with 1681 features.
# Fitting estimator with 1680 features.
# Fitting estimator with 1686 features.
# Fitting estimator with 1680 features.
# Fitting estimator with 1679 features.
# Fitting estimator with 1685 features.
# Fitting estimator with 1679 features.
# Fitting estimator with 1678 features.
# Fitting estimator with 1684 features.
# Fitting estimator with 1678 features.
# Fitting estimator with 1677 features.
# Fitting estimator with 1683 features.
# Fitting estimator with 1677 features.
# Fitting estimator with 1676 features.
# Fitting estimator with 1682 features.
# Fitting estimator with 1676 features.
# Fitting estimator with 1675 features.
# Fitting estimator with 1681 features.
# Fitting estimator with 1675 features.
# Fitting estimator with 1674 features.
# Fitting estimator with 1680 features.
# Fitting estimator with 1674 features.
# Fitting estimator with 1673 features.
# Fitting estimator with 1679 features.
# Fitting estimator with 1673 features.
# Fitting estimator with 1672 features.
# Fitting estimator with 1678 features.
# Fitting estimator with 1672 features.
# Fitting estimator with 1671 features.
# Fitting estimator with 1677 features.
# Fitting estimator with 1671 features.
# Fitting estimator with 1670 features.
# Fitting estimator with 1670 features.
# Fitting estimator with 1676 features.
# Fitting estimator with 1669 features.
# Fitting estimator with 1669 features.
# Fitting estimator with 1675 features.
# Fitting estimator with 1668 features.
# Fitting estimator with 1668 features.
# Fitting estimator with 1674 features.
# Fitting estimator with 1667 features.
# Fitting estimator with 1667 features.
# Fitting estimator with 1673 features.
# Fitting estimator with 1666 features.
# Fitting estimator with 1666 features.
# Fitting estimator with 1672 features.
# Fitting estimator with 1665 features.
# Fitting estimator with 1665 features.
# Fitting estimator with 1671 features.
# Fitting estimator with 1664 features.
# Fitting estimator with 1664 features.
# Fitting estimator with 1670 features.
# Fitting estimator with 1663 features.
# Fitting estimator with 1663 features.
# Fitting estimator with 1669 features.
# Fitting estimator with 1662 features.
# Fitting estimator with 1662 features.
# Fitting estimator with 1668 features.
# Fitting estimator with 1661 features.
# Fitting estimator with 1661 features.
# Fitting estimator with 1667 features.
# Fitting estimator with 1660 features.
# Fitting estimator with 1660 features.
# Fitting estimator with 1666 features.
# Fitting estimator with 1659 features.
# Fitting estimator with 1659 features.
# Fitting estimator with 1665 features.
# Fitting estimator with 1658 features.
# Fitting estimator with 1658 features.
# Fitting estimator with 1664 features.
# Fitting estimator with 1657 features.
# Fitting estimator with 1657 features.
# Fitting estimator with 1663 features.
# Fitting estimator with 1656 features.
# Fitting estimator with 1656 features.
# Fitting estimator with 1662 features.
# Fitting estimator with 1655 features.
# Fitting estimator with 1655 features.
# Fitting estimator with 1661 features.
# Fitting estimator with 1654 features.
# Fitting estimator with 1654 features.
# Fitting estimator with 1660 features.
# Fitting estimator with 1653 features.
# Fitting estimator with 1653 features.
# Fitting estimator with 1659 features.
# Fitting estimator with 1652 features.
# Fitting estimator with 1652 features.
# Fitting estimator with 1651 features.
# Fitting estimator with 1658 features.
# Fitting estimator with 1651 features.
# Fitting estimator with 1650 features.
# Fitting estimator with 1657 features.
# Fitting estimator with 1650 features.
# Fitting estimator with 1649 features.
# Fitting estimator with 1656 features.
# Fitting estimator with 1649 features.
# Fitting estimator with 1648 features.
# Fitting estimator with 1655 features.
# Fitting estimator with 1648 features.
# Fitting estimator with 1647 features.
# Fitting estimator with 1654 features.
# Fitting estimator with 1647 features.
# Fitting estimator with 1646 features.
# Fitting estimator with 1653 features.
# Fitting estimator with 1646 features.
# Fitting estimator with 1645 features.
# Fitting estimator with 1652 features.
# Fitting estimator with 1645 features.
# Fitting estimator with 1644 features.
# Fitting estimator with 1651 features.
# Fitting estimator with 1644 features.
# Fitting estimator with 1643 features.
# Fitting estimator with 1643 features.
# Fitting estimator with 1650 features.
# Fitting estimator with 1642 features.
# Fitting estimator with 1642 features.
# Fitting estimator with 1649 features.
# Fitting estimator with 1641 features.
# Fitting estimator with 1641 features.
# Fitting estimator with 1648 features.
# Fitting estimator with 1640 features.
# Fitting estimator with 1640 features.
# Fitting estimator with 1647 features.
# Fitting estimator with 1639 features.
# Fitting estimator with 1639 features.
# Fitting estimator with 1646 features.
# Fitting estimator with 1638 features.
# Fitting estimator with 1638 features.
# Fitting estimator with 1645 features.
# Fitting estimator with 1637 features.
# Fitting estimator with 1637 features.
# Fitting estimator with 1644 features.
# Fitting estimator with 1636 features.
# Fitting estimator with 1636 features.
# Fitting estimator with 1643 features.
# Fitting estimator with 1635 features.
# Fitting estimator with 1635 features.
# Fitting estimator with 1642 features.
# Fitting estimator with 1634 features.
# Fitting estimator with 1634 features.
# Fitting estimator with 1641 features.
# Fitting estimator with 1633 features.
# Fitting estimator with 1633 features.
# Fitting estimator with 1640 features.
# Fitting estimator with 1632 features.
# Fitting estimator with 1632 features.
# Fitting estimator with 1639 features.
# Fitting estimator with 1631 features.
# Fitting estimator with 1631 features.
# Fitting estimator with 1638 features.
# Fitting estimator with 1630 features.
# Fitting estimator with 1630 features.
# Fitting estimator with 1637 features.
# Fitting estimator with 1629 features.
# Fitting estimator with 1629 features.
# Fitting estimator with 1636 features.
# Fitting estimator with 1628 features.
# Fitting estimator with 1628 features.
# Fitting estimator with 1635 features.
# Fitting estimator with 1627 features.
# Fitting estimator with 1627 features.
# Fitting estimator with 1634 features.
# Fitting estimator with 1626 features.
# Fitting estimator with 1626 features.
# Fitting estimator with 1633 features.
# Fitting estimator with 1625 features.
# Fitting estimator with 1625 features.
# Fitting estimator with 1632 features.
# Fitting estimator with 1624 features.
# Fitting estimator with 1624 features.
# Fitting estimator with 1631 features.
# Fitting estimator with 1623 features.
# Fitting estimator with 1623 features.
# Fitting estimator with 1630 features.
# Fitting estimator with 1622 features.
# Fitting estimator with 1622 features.
# Fitting estimator with 1629 features.
# Fitting estimator with 1621 features.
# Fitting estimator with 1621 features.
# Fitting estimator with 1628 features.
# Fitting estimator with 1620 features.
# Fitting estimator with 1620 features.
# Fitting estimator with 1627 features.
# Fitting estimator with 1619 features.
# Fitting estimator with 1619 features.
# Fitting estimator with 1626 features.
# Fitting estimator with 1618 features.
# Fitting estimator with 1618 features.
# Fitting estimator with 1625 features.
# Fitting estimator with 1617 features.
# Fitting estimator with 1617 features.
# Fitting estimator with 1624 features.
# Fitting estimator with 1616 features.
# Fitting estimator with 1616 features.
# Fitting estimator with 1623 features.
# Fitting estimator with 1615 features.
# Fitting estimator with 1615 features.
# Fitting estimator with 1622 features.
# Fitting estimator with 1614 features.
# Fitting estimator with 1614 features.
# Fitting estimator with 1621 features.
# Fitting estimator with 1613 features.
# Fitting estimator with 1613 features.
# Fitting estimator with 1620 features.
# Fitting estimator with 1612 features.
# Fitting estimator with 1612 features.
# Fitting estimator with 1619 features.
# Fitting estimator with 1611 features.
# Fitting estimator with 1611 features.
# Fitting estimator with 1618 features.
# Fitting estimator with 1610 features.
# Fitting estimator with 1610 features.
# Fitting estimator with 1617 features.
# Fitting estimator with 1609 features.
# Fitting estimator with 1609 features.
# Fitting estimator with 1616 features.
# Fitting estimator with 1608 features.
# Fitting estimator with 1608 features.
# Fitting estimator with 1615 features.
# Fitting estimator with 1607 features.
# Fitting estimator with 1607 features.
# Fitting estimator with 1614 features.
# Fitting estimator with 1606 features.
# Fitting estimator with 1606 features.
# Fitting estimator with 1613 features.
# Fitting estimator with 1605 features.
# Fitting estimator with 1605 features.
# Fitting estimator with 1612 features.
# Fitting estimator with 1604 features.
# Fitting estimator with 1604 features.
# Fitting estimator with 1611 features.
# Fitting estimator with 1603 features.
# Fitting estimator with 1603 features.
# Fitting estimator with 1610 features.
# Fitting estimator with 1602 features.
# Fitting estimator with 1602 features.
# Fitting estimator with 1609 features.
# Fitting estimator with 1601 features.
# Fitting estimator with 1601 features.
# Fitting estimator with 1608 features.
# Fitting estimator with 1600 features.
# Fitting estimator with 1600 features.
# Fitting estimator with 1607 features.
# Fitting estimator with 1599 features.
# Fitting estimator with 1599 features.
# Fitting estimator with 1606 features.
# Fitting estimator with 1598 features.
# Fitting estimator with 1598 features.
# Fitting estimator with 1597 features.
# Fitting estimator with 1605 features.
# Fitting estimator with 1597 features.
# Fitting estimator with 1596 features.
# Fitting estimator with 1604 features.
# Fitting estimator with 1596 features.
# Fitting estimator with 1595 features.
# Fitting estimator with 1603 features.
# Fitting estimator with 1595 features.
# Fitting estimator with 1594 features.
# Fitting estimator with 1602 features.
# Fitting estimator with 1594 features.
# Fitting estimator with 1593 features.
# Fitting estimator with 1601 features.
# Fitting estimator with 1593 features.
# Fitting estimator with 1592 features.
# Fitting estimator with 1600 features.
# Fitting estimator with 1592 features.
# Fitting estimator with 1591 features.
# Fitting estimator with 1599 features.
# Fitting estimator with 1591 features.
# Fitting estimator with 1590 features.
# Fitting estimator with 1598 features.
# Fitting estimator with 1590 features.
# Fitting estimator with 1589 features.
# Fitting estimator with 1589 features.
# Fitting estimator with 1597 features.
# Fitting estimator with 1588 features.
# Fitting estimator with 1588 features.
# Fitting estimator with 1596 features.
# Fitting estimator with 1587 features.
# Fitting estimator with 1587 features.
# Fitting estimator with 1595 features.
# Fitting estimator with 1586 features.
# Fitting estimator with 1586 features.
# Fitting estimator with 1594 features.
# Fitting estimator with 1585 features.
# Fitting estimator with 1585 features.
# Fitting estimator with 1593 features.
# Fitting estimator with 1584 features.
# Fitting estimator with 1584 features.
# Fitting estimator with 1592 features.
# Fitting estimator with 1583 features.
# Fitting estimator with 1583 features.
# Fitting estimator with 1591 features.
# Fitting estimator with 1582 features.
# Fitting estimator with 1582 features.
# Fitting estimator with 1590 features.
# Fitting estimator with 1581 features.
# Fitting estimator with 1581 features.
# Fitting estimator with 1580 features.
# Fitting estimator with 1589 features.
# Fitting estimator with 1580 features.
# Fitting estimator with 1579 features.
# Fitting estimator with 1588 features.
# Fitting estimator with 1579 features.
# Fitting estimator with 1578 features.
# Fitting estimator with 1587 features.
# Fitting estimator with 1578 features.
# Fitting estimator with 1577 features.
# Fitting estimator with 1586 features.
# Fitting estimator with 1577 features.
# Fitting estimator with 1576 features.
# Fitting estimator with 1585 features.
# Fitting estimator with 1576 features.
# Fitting estimator with 1575 features.
# Fitting estimator with 1584 features.
# Fitting estimator with 1575 features.
# Fitting estimator with 1574 features.
# Fitting estimator with 1583 features.
# Fitting estimator with 1574 features.
# Fitting estimator with 1573 features.
# Fitting estimator with 1582 features.
# Fitting estimator with 1573 features.
# Fitting estimator with 1572 features.
# Fitting estimator with 1581 features.
# Fitting estimator with 1572 features.
# Fitting estimator with 1571 features.
# Fitting estimator with 1580 features.
# Fitting estimator with 1571 features.
# Fitting estimator with 1570 features.
# Fitting estimator with 1579 features.
# Fitting estimator with 1570 features.
# Fitting estimator with 1569 features.
# Fitting estimator with 1578 features.
# Fitting estimator with 1569 features.
# Fitting estimator with 1568 features.
# Fitting estimator with 1577 features.
# Fitting estimator with 1568 features.
# Fitting estimator with 1567 features.
# Fitting estimator with 1576 features.
# Fitting estimator with 1567 features.
# Fitting estimator with 1566 features.
# Fitting estimator with 1575 features.
# Fitting estimator with 1566 features.
# Fitting estimator with 1565 features.
# Fitting estimator with 1574 features.
# Fitting estimator with 1565 features.
# Fitting estimator with 1564 features.
# Fitting estimator with 1573 features.
# Fitting estimator with 1564 features.
# Fitting estimator with 1563 features.
# Fitting estimator with 1572 features.
# Fitting estimator with 1563 features.
# Fitting estimator with 1562 features.
# Fitting estimator with 1571 features.
# Fitting estimator with 1562 features.
# Fitting estimator with 1561 features.
# Fitting estimator with 1561 features.
# Fitting estimator with 1570 features.
# Fitting estimator with 1560 features.
# Fitting estimator with 1560 features.
# Fitting estimator with 1569 features.
# Fitting estimator with 1559 features.
# Fitting estimator with 1559 features.
# Fitting estimator with 1568 features.
# Fitting estimator with 1558 features.
# Fitting estimator with 1558 features.
# Fitting estimator with 1567 features.
# Fitting estimator with 1557 features.
# Fitting estimator with 1557 features.
# Fitting estimator with 1566 features.
# Fitting estimator with 1556 features.
# Fitting estimator with 1556 features.
# Fitting estimator with 1565 features.
# Fitting estimator with 1555 features.
# Fitting estimator with 1555 features.
# Fitting estimator with 1564 features.
# Fitting estimator with 1554 features.
# Fitting estimator with 1554 features.
# Fitting estimator with 1563 features.
# Fitting estimator with 1553 features.
# Fitting estimator with 1553 features.
# Fitting estimator with 1562 features.
# Fitting estimator with 1552 features.
# Fitting estimator with 1552 features.
# Fitting estimator with 1561 features.
# Fitting estimator with 1551 features.
# Fitting estimator with 1551 features.
# Fitting estimator with 1560 features.
# Fitting estimator with 1550 features.
# Fitting estimator with 1550 features.
# Fitting estimator with 1559 features.
# Fitting estimator with 1549 features.
# Fitting estimator with 1549 features.
# Fitting estimator with 1558 features.
# Fitting estimator with 1548 features.
# Fitting estimator with 1548 features.
# Fitting estimator with 1547 features.
# Fitting estimator with 1557 features.
# Fitting estimator with 1547 features.
# Fitting estimator with 1546 features.
# Fitting estimator with 1556 features.
# Fitting estimator with 1546 features.
# Fitting estimator with 1545 features.
# Fitting estimator with 1555 features.
# Fitting estimator with 1545 features.
# Fitting estimator with 1544 features.
# Fitting estimator with 1554 features.
# Fitting estimator with 1544 features.
# Fitting estimator with 1543 features.
# Fitting estimator with 1553 features.
# Fitting estimator with 1543 features.
# Fitting estimator with 1542 features.
# Fitting estimator with 1552 features.
# Fitting estimator with 1542 features.
# Fitting estimator with 1541 features.
# Fitting estimator with 1551 features.
# Fitting estimator with 1541 features.
# Fitting estimator with 1540 features.
# Fitting estimator with 1550 features.
# Fitting estimator with 1540 features.
# Fitting estimator with 1539 features.
# Fitting estimator with 1549 features.
# Fitting estimator with 1539 features.
# Fitting estimator with 1538 features.
# Fitting estimator with 1548 features.
# Fitting estimator with 1538 features.
# Fitting estimator with 1537 features.
# Fitting estimator with 1547 features.
# Fitting estimator with 1537 features.
# Fitting estimator with 1536 features.
# Fitting estimator with 1546 features.
# Fitting estimator with 1536 features.
# Fitting estimator with 1535 features.
# Fitting estimator with 1545 features.
# Fitting estimator with 1535 features.
# Fitting estimator with 1534 features.
# Fitting estimator with 1534 features.
# Fitting estimator with 1544 features.
# Fitting estimator with 1533 features.
# Fitting estimator with 1533 features.
# Fitting estimator with 1543 features.
# Fitting estimator with 1532 features.
# Fitting estimator with 1532 features.
# Fitting estimator with 1542 features.
# Fitting estimator with 1531 features.
# Fitting estimator with 1531 features.
# Fitting estimator with 1541 features.
# Fitting estimator with 1530 features.
# Fitting estimator with 1530 features.
# Fitting estimator with 1540 features.
# Fitting estimator with 1529 features.
# Fitting estimator with 1529 features.
# Fitting estimator with 1539 features.
# Fitting estimator with 1528 features.
# Fitting estimator with 1528 features.
# Fitting estimator with 1538 features.
# Fitting estimator with 1527 features.
# Fitting estimator with 1527 features.
# Fitting estimator with 1537 features.
# Fitting estimator with 1526 features.
# Fitting estimator with 1526 features.
# Fitting estimator with 1536 features.
# Fitting estimator with 1525 features.
# Fitting estimator with 1525 features.
# Fitting estimator with 1535 features.
# Fitting estimator with 1524 features.
# Fitting estimator with 1524 features.
# Fitting estimator with 1534 features.
# Fitting estimator with 1523 features.
# Fitting estimator with 1523 features.
# Fitting estimator with 1533 features.
# Fitting estimator with 1522 features.
# Fitting estimator with 1522 features.
# Fitting estimator with 1532 features.
# Fitting estimator with 1521 features.
# Fitting estimator with 1521 features.
# Fitting estimator with 1531 features.
# Fitting estimator with 1520 features.
# Fitting estimator with 1520 features.
# Fitting estimator with 1530 features.
# Fitting estimator with 1519 features.
# Fitting estimator with 1519 features.
# Fitting estimator with 1529 features.
# Fitting estimator with 1518 features.
# Fitting estimator with 1518 features.
# Fitting estimator with 1528 features.
# Fitting estimator with 1517 features.
# Fitting estimator with 1517 features.
# Fitting estimator with 1527 features.
# Fitting estimator with 1516 features.
# Fitting estimator with 1516 features.
# Fitting estimator with 1526 features.
# Fitting estimator with 1515 features.
# Fitting estimator with 1515 features.
# Fitting estimator with 1525 features.
# Fitting estimator with 1514 features.
# Fitting estimator with 1514 features.
# Fitting estimator with 1513 features.
# Fitting estimator with 1524 features.
# Fitting estimator with 1513 features.
# Fitting estimator with 1512 features.
# Fitting estimator with 1523 features.
# Fitting estimator with 1512 features.
# Fitting estimator with 1511 features.
# Fitting estimator with 1522 features.
# Fitting estimator with 1511 features.
# Fitting estimator with 1510 features.
# Fitting estimator with 1521 features.
# Fitting estimator with 1510 features.
# Fitting estimator with 1509 features.
# Fitting estimator with 1520 features.
# Fitting estimator with 1509 features.
# Fitting estimator with 1508 features.
# Fitting estimator with 1519 features.
# Fitting estimator with 1508 features.
# Fitting estimator with 1507 features.
# Fitting estimator with 1518 features.
# Fitting estimator with 1507 features.
# Fitting estimator with 1506 features.
# Fitting estimator with 1517 features.
# Fitting estimator with 1506 features.
# Fitting estimator with 1505 features.
# Fitting estimator with 1516 features.
# Fitting estimator with 1505 features.
# Fitting estimator with 1504 features.
# Fitting estimator with 1504 features.
# Fitting estimator with 1515 features.
# Fitting estimator with 1503 features.
# Fitting estimator with 1503 features.
# Fitting estimator with 1514 features.
# Fitting estimator with 1502 features.
# Fitting estimator with 1502 features.
# Fitting estimator with 1513 features.
# Fitting estimator with 1501 features.
# Fitting estimator with 1501 features.
# Fitting estimator with 1512 features.
# Fitting estimator with 1500 features.
# Fitting estimator with 1500 features.
# Fitting estimator with 1511 features.
# Fitting estimator with 1499 features.
# Fitting estimator with 1499 features.
# Fitting estimator with 1510 features.
# Fitting estimator with 1498 features.
# Fitting estimator with 1498 features.
# Fitting estimator with 1509 features.
# Fitting estimator with 1497 features.
# Fitting estimator with 1497 features.
# Fitting estimator with 1508 features.
# Fitting estimator with 1496 features.
# Fitting estimator with 1496 features.
# Fitting estimator with 1507 features.
# Fitting estimator with 1495 features.
# Fitting estimator with 1495 features.
# Fitting estimator with 1506 features.
# Fitting estimator with 1494 features.
# Fitting estimator with 1494 features.
# Fitting estimator with 1505 features.
# Fitting estimator with 1493 features.
# Fitting estimator with 1493 features.
# Fitting estimator with 1504 features.
# Fitting estimator with 1492 features.
# Fitting estimator with 1492 features.
# Fitting estimator with 1503 features.
# Fitting estimator with 1491 features.
# Fitting estimator with 1491 features.
# Fitting estimator with 1502 features.
# Fitting estimator with 1490 features.
# Fitting estimator with 1490 features.
# Fitting estimator with 1501 features.
# Fitting estimator with 1489 features.
# Fitting estimator with 1489 features.
# Fitting estimator with 1500 features.
# Fitting estimator with 1488 features.
# Fitting estimator with 1488 features.
# Fitting estimator with 1499 features.
# Fitting estimator with 1487 features.
# Fitting estimator with 1487 features.
# Fitting estimator with 1498 features.
# Fitting estimator with 1486 features.
# Fitting estimator with 1486 features.
# Fitting estimator with 1497 features.
# Fitting estimator with 1485 features.
# Fitting estimator with 1485 features.
# Fitting estimator with 1496 features.
# Fitting estimator with 1484 features.
# Fitting estimator with 1484 features.
# Fitting estimator with 1495 features.
# Fitting estimator with 1483 features.
# Fitting estimator with 1483 features.
# Fitting estimator with 1482 features.
# Fitting estimator with 1494 features.
# Fitting estimator with 1482 features.
# Fitting estimator with 1481 features.
# Fitting estimator with 1493 features.
# Fitting estimator with 1481 features.
# Fitting estimator with 1480 features.
# Fitting estimator with 1492 features.
# Fitting estimator with 1480 features.
# Fitting estimator with 1479 features.
# Fitting estimator with 1491 features.
# Fitting estimator with 1479 features.
# Fitting estimator with 1478 features.
# Fitting estimator with 1490 features.
# Fitting estimator with 1478 features.
# Fitting estimator with 1477 features.
# Fitting estimator with 1489 features.
# Fitting estimator with 1477 features.
# ...
# Fitting estimator with 27 features.
# Fitting estimator with 29 features.
# Fitting estimator with 116 features.
# Fitting estimator with 26 features.
# Fitting estimator with 28 features.
# Fitting estimator with 115 features.
# Fitting estimator with 25 features.
# Fitting estimator with 27 features.
# Fitting estimator with 24 features.
# Fitting estimator with 114 features.
# Fitting estimator with 26 features.
# Fitting estimator with 23 features.
# Fitting estimator with 25 features.
# Fitting estimator with 113 features.
# Fitting estimator with 22 features.
# Fitting estimator with 24 features.
# Fitting estimator with 21 features.
# Fitting estimator with 112 features.
# Fitting estimator with 23 features.
# Fitting estimator with 20 features.
# Fitting estimator with 111 features.
# Fitting estimator with 22 features.
# Fitting estimator with 19 features.
# Fitting estimator with 21 features.
# Fitting estimator with 18 features.
# Fitting estimator with 110 features.
# Fitting estimator with 20 features.
# Fitting estimator with 17 features.
# Fitting estimator with 109 features.
# Fitting estimator with 19 features.
# Fitting estimator with 16 features.
# Fitting estimator with 18 features.
# Fitting estimator with 108 features.
# Fitting estimator with 15 features.
# Fitting estimator with 17 features.
# Fitting estimator with 14 features.
# Fitting estimator with 107 features.
# Fitting estimator with 16 features.
# Fitting estimator with 13 features.
# Fitting estimator with 106 features.
# Fitting estimator with 15 features.
# Fitting estimator with 12 features.
# Fitting estimator with 14 features.
# Fitting estimator with 11 features.
# Fitting estimator with 105 features.
# Fitting estimator with 13 features.
# Fitting estimator with 10 features.
# Fitting estimator with 104 features.
# Fitting estimator with 12 features.
# Fitting estimator with 9 features.
# Fitting estimator with 11 features.
# Fitting estimator with 8 features.
# Fitting estimator with 103 features.
# Fitting estimator with 10 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 9 features.
# Fitting estimator with 102 features.
# Fitting estimator with 5 features.
# Fitting estimator with 8 features.
# Fitting estimator with 101 features.
# Fitting estimator with 4 features.
# Fitting estimator with 7 features.
# Fitting estimator with 3 features.
# Fitting estimator with 6 features.
# Fitting estimator with 100 features.
# Fitting estimator with 2 features.
# Fitting estimator with 5 features.
# Fitting estimator with 99 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 98 features.
# Fitting estimator with 2 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 1901 features.
# Fitting estimator with 1900 features.
# Fitting estimator with 1899 features.
# Fitting estimator with 1898 features.
# Fitting estimator with 1897 features.
# Fitting estimator with 1896 features.
# Fitting estimator with 1895 features.
# Fitting estimator with 1894 features.
# Fitting estimator with 1893 features.
# Fitting estimator with 1892 features.
# Fitting estimator with 1891 features.
# Fitting estimator with 1890 features.
# Fitting estimator with 1889 features.
# Fitting estimator with 1888 features.
# Fitting estimator with 1887 features.
# Fitting estimator with 1886 features.
# Fitting estimator with 1885 features.
# Fitting estimator with 1884 features.
# Fitting estimator with 1883 features.
# Fitting estimator with 1882 features.
# Fitting estimator with 1881 features.
# Fitting estimator with 1880 features.
# Fitting estimator with 1879 features.
# Fitting estimator with 1878 features.
# Fitting estimator with 1877 features.
# Fitting estimator with 1876 features.
# Fitting estimator with 1875 features.
# Fitting estimator with 1874 features.
# Fitting estimator with 1873 features.
# Fitting estimator with 1872 features.
# Fitting estimator with 1871 features.
# Fitting estimator with 1870 features.
# Fitting estimator with 1869 features.
# Fitting estimator with 1868 features.
# Fitting estimator with 1867 features.
# Fitting estimator with 1866 features.
# Fitting estimator with 1865 features.
# Fitting estimator with 1864 features.
# Fitting estimator with 1863 features.
# Fitting estimator with 1862 features.
# Fitting estimator with 1861 features.
# Fitting estimator with 1860 features.
# Fitting estimator with 1859 features.
# Fitting estimator with 1858 features.
# Fitting estimator with 1857 features.
# Fitting estimator with 1856 features.
# Fitting estimator with 1855 features.
# Fitting estimator with 1854 features.
# Fitting estimator with 1853 features.
# Fitting estimator with 1852 features.
# Fitting estimator with 1851 features.
# Fitting estimator with 1850 features.
# Fitting estimator with 1849 features.
# Fitting estimator with 1848 features.
# Fitting estimator with 1847 features.
# Fitting estimator with 1846 features.
# Fitting estimator with 1845 features.
# Fitting estimator with 1844 features.
# Fitting estimator with 1843 features.
# Fitting estimator with 1842 features.
# Fitting estimator with 1841 features.
# Fitting estimator with 1840 features.
# Fitting estimator with 1839 features.
# Fitting estimator with 1838 features.
# Fitting estimator with 1837 features.
# Fitting estimator with 1836 features.
# Fitting estimator with 1835 features.
# Fitting estimator with 1834 features.
# Fitting estimator with 1833 features.
# Fitting estimator with 1832 features.
# Fitting estimator with 1831 features.
# Fitting estimator with 1830 features.
# Fitting estimator with 1829 features.
# Fitting estimator with 1828 features.
# Fitting estimator with 1827 features.
# Fitting estimator with 1826 features.
# Fitting estimator with 1825 features.
# Fitting estimator with 1824 features.
# Fitting estimator with 1823 features.
# Fitting estimator with 1822 features.
# Fitting estimator with 1821 features.
# Fitting estimator with 1820 features.
# Fitting estimator with 1819 features.
# Fitting estimator with 1818 features.
# Fitting estimator with 1817 features.
# Fitting estimator with 1816 features.
# Fitting estimator with 1815 features.
# Fitting estimator with 1814 features.
# Fitting estimator with 1813 features.
# Fitting estimator with 1812 features.
# Fitting estimator with 1811 features.
# Fitting estimator with 1810 features.
# Fitting estimator with 1809 features.
# Fitting estimator with 1808 features.
# Fitting estimator with 1807 features.
# Fitting estimator with 1806 features.
# Fitting estimator with 1805 features.
# Fitting estimator with 1804 features.
# Fitting estimator with 1803 features.
# Fitting estimator with 1802 features.
# Fitting estimator with 1801 features.
# Fitting estimator with 1800 features.
# Fitting estimator with 1799 features.
# Fitting estimator with 1798 features.
# Fitting estimator with 1797 features.
# Fitting estimator with 1796 features.
# Fitting estimator with 1795 features.
# Fitting estimator with 1794 features.
# Fitting estimator with 1793 features.
# Fitting estimator with 1792 features.
# Fitting estimator with 1791 features.
# Fitting estimator with 1790 features.
# Fitting estimator with 1789 features.
# Fitting estimator with 1788 features.
# Fitting estimator with 1787 features.
# Fitting estimator with 1786 features.
# Fitting estimator with 1785 features.
# Fitting estimator with 1784 features.
# Fitting estimator with 1783 features.
# Fitting estimator with 1782 features.
# Fitting estimator with 1781 features.
# Fitting estimator with 1780 features.
# Fitting estimator with 1779 features.
# Fitting estimator with 1778 features.
# Fitting estimator with 1777 features.
# Fitting estimator with 1776 features.
# Fitting estimator with 1775 features.
# Fitting estimator with 1774 features.
# Fitting estimator with 1773 features.
# Fitting estimator with 1772 features.
# Fitting estimator with 1771 features.
# Fitting estimator with 1770 features.
# Fitting estimator with 1769 features.
# Fitting estimator with 1768 features.
# Fitting estimator with 1767 features.
# Fitting estimator with 1766 features.
# Fitting estimator with 1765 features.
# Fitting estimator with 1764 features.
# Fitting estimator with 1763 features.
# Fitting estimator with 1762 features.
# Fitting estimator with 1761 features.
# Fitting estimator with 1760 features.
# Fitting estimator with 1759 features.
# Fitting estimator with 1758 features.
# Fitting estimator with 1757 features.
# Fitting estimator with 1756 features.
# Fitting estimator with 1755 features.
# Fitting estimator with 1754 features.
# Fitting estimator with 1753 features.
# Fitting estimator with 1752 features.
# Fitting estimator with 1751 features.
# Fitting estimator with 1750 features.
# Fitting estimator with 1749 features.
# Fitting estimator with 1748 features.
# Fitting estimator with 1747 features.
# Fitting estimator with 1746 features.
# Fitting estimator with 1745 features.
# Fitting estimator with 1744 features.
# Fitting estimator with 1743 features.
# Fitting estimator with 1742 features.
# Fitting estimator with 1741 features.
# Fitting estimator with 1740 features.
# Fitting estimator with 1739 features.
# Fitting estimator with 1738 features.
# Fitting estimator with 1737 features.
# Fitting estimator with 1736 features.
# Fitting estimator with 1735 features.
# Fitting estimator with 1734 features.
# Fitting estimator with 1733 features.
# Fitting estimator with 1732 features.
# Fitting estimator with 1731 features.
# Fitting estimator with 1730 features.
# Fitting estimator with 1729 features.
# Fitting estimator with 1728 features.
# Fitting estimator with 1727 features.
# Fitting estimator with 1726 features.
# Fitting estimator with 1725 features.
# Fitting estimator with 1724 features.
# Fitting estimator with 1723 features.
# Fitting estimator with 1722 features.
# Fitting estimator with 1721 features.
# Fitting estimator with 1720 features.
# Fitting estimator with 1719 features.
# Fitting estimator with 1718 features.
# Fitting estimator with 1717 features.
# Fitting estimator with 1716 features.
# Fitting estimator with 1715 features.
# Fitting estimator with 1714 features.
# Fitting estimator with 1713 features.
# Fitting estimator with 1712 features.
# Fitting estimator with 1711 features.
# Fitting estimator with 1710 features.
# Fitting estimator with 1709 features.
# Fitting estimator with 1708 features.
# Fitting estimator with 1707 features.
# Fitting estimator with 1706 features.
# Fitting estimator with 1705 features.
# Fitting estimator with 1704 features.
# Fitting estimator with 1703 features.
# Fitting estimator with 1702 features.
# Fitting estimator with 1701 features.
# Fitting estimator with 1700 features.
# Fitting estimator with 1699 features.
# Fitting estimator with 1698 features.
# Fitting estimator with 1697 features.
# Fitting estimator with 1696 features.
# Fitting estimator with 1695 features.
# Fitting estimator with 1694 features.
# Fitting estimator with 1693 features.
# Fitting estimator with 1692 features.
# Fitting estimator with 1691 features.
# Fitting estimator with 1690 features.
# Fitting estimator with 1689 features.
# Fitting estimator with 1688 features.
# Fitting estimator with 1687 features.
# Fitting estimator with 1686 features.
# Fitting estimator with 1685 features.
# Fitting estimator with 1684 features.
# Fitting estimator with 1683 features.
# Fitting estimator with 1682 features.
# Fitting estimator with 1681 features.
# Fitting estimator with 1680 features.
# Fitting estimator with 1679 features.
# Fitting estimator with 1678 features.
# Fitting estimator with 1677 features.
# Fitting estimator with 1676 features.
# Fitting estimator with 1675 features.
# Fitting estimator with 1674 features.
# Fitting estimator with 1673 features.
# Fitting estimator with 1672 features.
# Fitting estimator with 1671 features.
# Fitting estimator with 1670 features.
# Fitting estimator with 1669 features.
# Fitting estimator with 1668 features.
# Fitting estimator with 1667 features.
# Fitting estimator with 1666 features.
# Fitting estimator with 1665 features.
# Fitting estimator with 1664 features.
# Fitting estimator with 1663 features.
# Fitting estimator with 1662 features.
# Fitting estimator with 1661 features.
# Fitting estimator with 1660 features.
# Fitting estimator with 1659 features.
# Fitting estimator with 1658 features.
# Fitting estimator with 1657 features.
# Fitting estimator with 1656 features.
# Fitting estimator with 1655 features.
# Fitting estimator with 1654 features.
# Fitting estimator with 1653 features.
# Fitting estimator with 1652 features.
# Fitting estimator with 1651 features.
# Number of selected features by RFECV: 1650
# Eliminated features by RFECV: 251
# Original number of features (after RFECV): 1650
# Number of components selected by PCA: 90
# Final shape of the train dataset: (305, 90)
# Final shape of the test dataset: (100, 90)
# Final shape of the training part of the train dataset: (244, 90)
# Final shape of the testing part of the train dataset: (61, 90)

# %% [markdown]
# ### Grid Search

# %%
mlp = MLPClassifier(random_state=2023)

param_grid = {
    'hidden_layer_sizes': [(100,), (100,50), (50,50)],
    'activation': ['tanh', 'relu'],
    'solver': ['lbfgs','adam'],
    'alpha': [0.0001, 0.001],
    'learning_rate': ['constant','adaptive', 'invscaling'],
    'max_iter': [1000, 1500],
    'early_stopping': [True, False],
    'n_iter_no_change': [5, 10],
    'batch_size': [32, 'auto']
}


grid_searchMLP = GridSearchCV(mlp, param_grid, cv=3, refit=True,verbose=3, scoring='f1_macro')
grid_searchMLP.fit(X_train_final, y_train)
grid_predicitionMLP = grid_searchMLP.predict(X_val_final)

print("Best estimator: ", grid_searchMLP.best_estimator_)
print("Best parameters: ", grid_searchMLP.best_params_)

print(classification_report(y_val, grid_predicitionMLP))
ConfusionMatrixDisplay.from_predictions(y_val, grid_predicitionMLP)
plt.show()
# Out:
# Fitting 3 folds for each of 1152 candidates, totalling 3456 fits
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.319 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.280 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.195 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.326 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.296 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.451 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.253 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.324 total time=   0.1s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.310 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.300 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.349 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.211 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.272 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.266 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=True, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.325 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.295 total time=   0.0s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.370 total time=   0.0s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.229 total time=   0.0s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.317 total time=   0.5s
# [CV 2/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.420 total time=   0.5s
# [CV 3/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.274 total time=   0.4s
# [CV 1/3] END activation=tanh, alpha=0.0001, batch_size=32, early_stopping=False, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.295 total time=   0.0s
# ...
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.2s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=constant, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.2s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.2s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=adaptive, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1000, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=5, solver=adam;, score=0.269 total time=   0.1s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.282 total time=   0.0s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.387 total time=   0.0s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=lbfgs;, score=0.241 total time=   0.0s
# [CV 1/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.361 total time=   0.1s
# [CV 2/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.267 total time=   0.1s
# [CV 3/3] END activation=relu, alpha=0.001, batch_size=auto, early_stopping=False, hidden_layer_sizes=(50, 50), learning_rate=invscaling, max_iter=1500, n_iter_no_change=10, solver=adam;, score=0.269 total time=   0.2s
# Best estimator:  MLPClassifier(activation='tanh', batch_size=32, hidden_layer_sizes=(100, 50),
#               max_iter=1000, random_state=2023)
# Best parameters:  {'activation': 'tanh', 'alpha': 0.0001, 'batch_size': 32, 'early_stopping': False, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'n_iter_no_change': 10, 'solver': 'adam'}
#               precision    recall  f1-score   support
#
#        AD-AD       0.31      0.42      0.36        12
#        CN-CN       0.57      0.42      0.48        19
#       CN-MCI       0.00      0.00      0.00         2
#       MCI-AD       0.25      0.21      0.23        14
#      MCI-MCI       0.44      0.57      0.50        14
#
#     accuracy                           0.39        61
#    macro avg       0.32      0.32      0.31        61
# weighted avg       0.40      0.39      0.39        61

# %% [markdown]
# ### MLP Prediction

# %%
mlp = MLPClassifier(activation='tanh', batch_size=32, hidden_layer_sizes=(100, 50), max_iter=1000, random_state=2023)
mlp.fit(X_final, y)
predictionsMLP = mlp.predict(X_test_final)

with open('../../predictions/mlp.csv', 'w') as results:
    results.write('RowId,Result\n')
    i = 1
    for p in predictionsMLP:
        results.write(f'{i},{p}\n')
        i+=1
